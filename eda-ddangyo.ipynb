# %% [markdown]
# # EDA 땡겨요 리뷰

# %%
# 0) Package Import

# Data Processing
import numpy as np
import pandas as pd
import re

# NLP
from konlpy.tag import Okt # twitter dev
from konlpy.tag import Kkma # konlpy.tag : Okt, Kkma
from konlpy.utils import pprint
from kiwipiepy import Kiwi 

# Visualization
import matplotlib.pyplot as plt
import koreanize_matplotlib
import seaborn as sns

# WordCloud
from PIL import Image
from wordcloud import WordCloud
from collections import Counter

# LDA
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import pyLDAvis.lda_model 

# 장바구니 분석
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
import networkx as nx

# %% [markdown]
# ## 1. Data Setting

# %%
# 1) Data 확인
raw_cus_data = pd.read_csv('data/구글플레이스토어_땡겨요_리뷰.csv')

raw_sel_data = pd.read_csv('data/구글플레이스토어_땡겨요주문접수_리뷰.csv')

# 결측치 및 type 확인
print(raw_cus_data.info()) # 1940개(결측치 x, 연속성 data type 확인)
print(raw_sel_data.info()) # 55개(결측치 x, 연속성 data type 확인)

# ** 사용자 리뷰 1940개 / 판매자 리뷰 55개 ⇒ 사용자 리뷰 분석에 중점
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1940 entries, 0 to 1939
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1940 non-null   int64
#  1   customer_id  1940 non-null   object
#  2   star         1940 non-null   int64
#  3   enroll_date  1940 non-null   object
#  4   content      1940 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 75.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   55 non-null     int64
#  1   customer_id  55 non-null     object
#  2   star         55 non-null     int64
#  3   enroll_date  55 non-null     object
#  4   content      55 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 2.3+ KB
# None

# %%
# 2) 긍부정 column 추가(기준 Data 생성)
raw_cus_data['favor'] = np.where(raw_cus_data['star'] >= 4, 1, 0)
raw_sel_data['favor'] = np.where(raw_sel_data['star'] >= 4, 1, 0)

cus_data = raw_cus_data
sel_data = raw_sel_data

cus_list = cus_data['content'].tolist()
sel_list = sel_data['content'].tolist()

# %%
# 3) List로 추출(불용어 처리/유효성 검사)

okt = Okt()

stop_words = ['주문', '배달', '쿠폰', '메뉴', '어플', '결제', '가게', '사용'] 

def make_word_list(content_list):

    word_list = []

    for content in content_list:

        # 1. 정규표현식 정제
        review = re.sub(r'[^0-9a-zA-Z가-힣\s+-]', '', content)

        # 2. 형태소 분석
        result = okt.nouns(review)

        for word in result:
            if len(word) > 1 and word not in stop_words:
                word_list.append(word)
                
    return word_list

cus_word_list = make_word_list(cus_list)
sel_word_list = make_word_list(sel_list)

print(len(cus_word_list))  
print(len(sel_word_list))
# Out:
# 17322
# 326

# %% [markdown]
# ## 2. 워드 클라우드 분석

# %%
def make_word_cloud(word_list, keyword_amount, title):
    
    counter = Counter(word_list).most_common(keyword_amount)

    circle_mask = np.array(Image.open(r'resources\circle.png'))

    wc = WordCloud(
        font_path=r"C:\Windows\Fonts\H2GTRM.TTF",
        background_color="black", # white
        mask=circle_mask,
        colormap="jet", # https://www.kaggle.com/code/niteshhalai/wordcloud-colormap
        width=1200,
        height=1200,
        scale=10 # 결과 이미지의 해상도를 높히고 싶을때 
    )

    wc.generate_from_frequencies(dict(counter))

    plt.figure(figsize=(5,5))
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(title, fontsize=20)
    plt.show()

# %%
make_word_cloud(cus_word_list, 50, '땡겨요 소비자(명사)')    
# ⇒ 주목할 단어 : 할인, 배민, 다른, 그냥
#    ‘배민’에 대한 비교나 ‘그냥’ ‘다른’ 등의 키워드를 통해 
#     땡겨요를 시켜야 할 큰 특장점을 느끼지 못함을 유추 가능
# Out:
# c:\walker\code\eda-ddangyo\.venv\Lib\site-packages\matplotlib\cbook.py:684: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   x = np.array(x, subok=True, copy=copy)

# %%
# 소비자 리뷰 중에서 특정 키워드가 들어간 리뷰들 워드 클라우드

cus_keyword = '지역'
cus_keyword_list = cus_data.loc[cus_data['content'].str.contains(cus_keyword),:]['content']

cus_keyword_word_list = make_word_list(cus_keyword_list)

make_word_cloud(cus_keyword_word_list, 50, f'땡겨요 소비자(명사) - 키워드 {cus_keyword}')
#  ⇒ 주목할 단어 : 검색 키워드가 ‘서울페이’임에도 혜택 관련 내용이 아니라, 
#        ‘오류’, ‘연동’, ‘문제’ 등의 시스템 에러 관련 키워드가 주로 발견됨 
#         → 서울페이 등록 및 사용 과정에 시스템 에러가 발생하는지 확인 필요
# Out:
# c:\walker\code\eda-ddangyo\.venv\Lib\site-packages\matplotlib\cbook.py:684: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   x = np.array(x, subok=True, copy=copy)

# %%
make_word_cloud(sel_word_list, 50, '땡겨요 판매자(명사)')    
# ⇒ 주목할 키워드 : 먹통, 종료, 위험, 유출
# → 전체 키워드에 비해 상품권에서 더 강한 시스템 오류에 대한 불만을 
#      ‘종료’ ‘먹통’ 등의 키워드를 통해 알 수 있음 : 전반적 시스템 확인 필요
# Out:
# c:\walker\code\eda-ddangyo\.venv\Lib\site-packages\matplotlib\cbook.py:684: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   x = np.array(x, subok=True, copy=copy)

# %%
# 판매자 리뷰 중에서 특정 키워드가 들어간 리뷰들 워드 클라우드

sel_keyword = '지역'
sel_keyword_list = sel_data.loc[sel_data['content'].str.contains(sel_keyword),:]['content']

sel_keyword_word_list = make_word_list(sel_keyword_list)

make_word_cloud(sel_keyword_word_list, 50, f'땡겨요 판매자(명사) - 키워드 {sel_keyword}')
# ⇒ 주목할 키워드 : 먹통, 종료, 위험, 유출
# → 전체 키워드에 비해 상품권에서 더 강한 시스템 오류에 대한 불만을 
#      ‘종료’ ‘먹통’ 등의 키워드를 통해 알 수 있음 : 전반적 시스템 확인 필요
# Out:
# c:\walker\code\eda-ddangyo\.venv\Lib\site-packages\matplotlib\cbook.py:684: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   x = np.array(x, subok=True, copy=copy)

# %% [markdown]
# ## 3. 긍부정 분석

# %%
# 소비자 긍정 리뷰 분석

cus_pos_list = cus_data.loc[cus_data['favor'] == 1, :]['content']
make_word_str(cus_pos_list)
cus_pos_word_list = make_word_list(cus_pos_list)

make_word_cloud(cus_pos_word_list, 50, '땡겨요 소비자(명사) - 긍정')
# 워드클라우드
# ⇒ 주목할 단어 : 지역화폐, 상품권, 서울, 페이
#    지역상품권 그 중에서도 서울페이에 대한 키워드가 
#    긍정 리뷰를 남긴 사용자 사이에서 나오는 상황
# Out:
# c:\walker\code\eda-ddangyo\.venv\Lib\site-packages\matplotlib\cbook.py:684: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   x = np.array(x, subok=True, copy=copy)

# %%
# lda 데이터 전처리
def for_lda_data(content_list):

    lda_list = []

    for review in content_list:

        rv = re.sub(r"[^0-9a-zA-Z가-힣+-]", "", review)

        result = okt.morphs(rv)

        if result not in stop_words:
            lda_list.append(' '.join(result)) # vectorize를 위한 공백(' ') 구분 형태로 review 전처리
    
    return lda_list

# %%
# 소비자 긍정 리뷰 lda
cus_pos_lda_list = for_lda_data(cus_pos_list)

vectorizer = CountVectorizer(
    max_df = 0.1,               # 전체 단어 등장 비율이 p 이상인 것만 사용할 것.
    min_df = 2,                 # 단어가 적어도 n개 이상인 것만 사용할 것.
    max_features = 1000,        # 상위 항목 n개만 사용할 것.
    ngram_range= (1,2)          # 단어(ngram)의 조합
)

feature_vec = vectorizer.fit_transform(cus_pos_lda_list)
feature_vec.shape

lda = LatentDirichletAllocation(n_components=3)
lda.fit(feature_vec)

pyLDAvis.enable_notebook()
vis = pyLDAvis.lda_model.prepare(l
c785\uc810", "\uc88b\uaca0\uc2b5\ub2c8\ub2e4", "\uc8fc\ubb38", "\uac00\uac8c", "\uc5d0\uc11c", "\uc218\uc218\ub8cc", "\ud560\uc778 \ub9ce\uc774", "\ub108\ubb34 \uc88b\uc544\uc694", "\ud3b8\ud574\uc694", "\ube44\ub3c4", "\ubc30\ub2ec \ube44\ub3c4", "\ub108\ubb34 \ub108\ubb34", "\ub9cc\ub098\uc11c", "\uc5d0\uac8c \ub3c4\uc6c0", "\ubc30\uc1a1", "\ub418\uc5c8\uc73c\uba74", "\uc88b\uc744\uac83", "\ucd94\ucc9c \ud569\ub2c8\ub2e4", "\uc5ec\ub7ec \uac00\uac8c", "\ub85c\ub529", "\ubc30\ubbfc \ucfe0\ ...

# %%
# 소비자 부정 리뷰 분석

cus_neg_list = cus_data.loc[cus_data['favor'] == 0, :]['content']

cus_neg_word_list = make_word_list(cus_neg_list)

make_word_cloud(cus_neg_word_list, 50, '땡겨요 소비자(명사) - 부정')
# ⇒ 주목할 단어 : 할인, 배민, 다른, 
# 부정 리뷰 분석에서 ‘할인’이라는 긍정 키워드가 높은 빈도로 나오는 것으로 보아
# ’할인’이 ‘다른’ 서비스, ‘배민’ 등에 비해 낮은 것으로 유추됨
# Out:
# c:\walker\code\eda-ddangyo\.venv\Lib\site-packages\matplotlib\cbook.py:684: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   x = np.array(x, subok=True, copy=copy)

# %%
# 소비자 부정 리뷰 lda
cus_neg_lda_list = for_lda_data(cus_neg_list)

vectorizer = CountVectorizer(
    max_df = 0.1,               # 전체 단어 등장 비율이 p 이상인 것만 사용할 것.
    min_df = 2,                 # 단어가 적어도 n개 이상인 것만 사용할 것.
    max_features = 1000,        # 상위 항목 n개만 사용할 것.
    ngram_range= (1,2)          # 단어(ngram)의 조합
)

feature_vec = vectorizer.fit_transform(cus_neg_lda_list)
feature_vec.shape

lda = LatentDirichletAllocation(n_components=3)
lda.fit(feature_vec)

pyLDAvis.enable_notebook()
vis = pyLDAvis.lda_model.prepare(lda, feature_vec, vectorizer)
pyLDAvis.display(vis)

# ⇒ 부정리뷰 LDA에서도 ‘배민’이라는 키워드가 ‘다른 배달’이라는 키워드와 함께 
#      ‘불만’ Topic 부류에서 함께 발견 → 소비자의 서비스 기준치가 배민에 맞춰져 있음
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el3024025009768785125549610559" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el3024025009768785125549610559_data = {"mdsDat": {"x": [-0.09179888428767581, -0.05870384357598332, 0.15050272786365917], "y": [0.11290459812464779, -0.1307653290078098, 0.017860730883162024], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [42.001752699654546, 32.21583832170952, 25.782408978635946]}, "tinfo": {"Term": ["\uc9c0\uc5ed", "\ud398\uc774", "\ubc30\ubbfc", "\ub85c\ub529", "500\uc6d0", "\ucde8\uc18c", "\ub124\ud2b8\uc6cc\ud06c", "\uc8fc\ubb38 \ucde8\uc18c", "\uacc4\uc18d", "\ud654\uba74", "1\uc2dc\uac04", "\uace0\uac1d", "\uc624\ub958", "\uad11\uace0", "\uc0c1\ud488\uad8c", "\uc811\uc18d", "\ubb34\ub8cc", "\uc2dc\ucf1c", "\uce74\ub4dc", "\ubc
a1", "\uc0ac\ub791 \uc0c1\ud488\uad8c", "\uc124\uce58 \ud574\ub3c4", "\ub9c8\ucf00\ud305", "\ud1b5\uc7a5", "\uc218\ub2e8", "\uc778\uc9c0", "\uc2dc\ucf1c", "\uc0c1\ud488\uad8c", "\uacc4\uc18d", "\uc624\ub958", "\ud3ec\uc778\ud2b8", "\uc2dd\ub2f9", "\uc11c\uc6b8", "\uadf8\ub9ac\uace0", "\uc218\uc815", "\uc5c6\uace0", "\uc88b\uc740\ub370", "\uac1c\uc120", "\uc811\uc18d", "\uac19\uc740", "\ub77c\uace0", "\ud574\uc11c", "\uc9c4\uc9dc", "\uac19\uc544\uc694", "\ubb38\uc81c", "\uc774\ubca4\ud2b8", "\uc644\ub8cc", "\ud588\ub294\ub370", "\ub9ce\uc774", "\ub9ac\ubdf0", "\uac00\uc785", "\uc124\uce58", "\uc774\uc6a9", "\uc785\ub2c8\ub2e4", "\uc774\ub098", "500\uc6d0", "\uc8fc\ubb38 \ucde8\uc18c", "1\uc2dc\uac04", "1000\uc6d0", "\ubc30\ubbfc \uc774\ub098", "\ubb34\ud55c", "\ud1a0\uc2a4", "\uc815\ubcf4", "\ubb34\ud55c \ub85c\ub529", "\ub9ce\uc74c", "\uc2e0\uacbd", "\uc88b\uc74c", "2\uc2dc\uac04", "3\ucc9c\uc6d0", "\ucc28\uc774", "\uc6b0\uc120", "\ud654\uba74", "\ud22c\uc790", "\ub290\ub824\uc694", "\uac00\ub054", "\ub354\ube44", "\uac1c\ubc1c\uc790", "\ubc45\ud06c", "\ud1a0\uc2a4 \ubc45\ud06c", "\ub108\ubb34 \ub290\ub824\uc694", "\uc791\ub3d9", "\ubd88\ud3b8\ud568", "\uc2dc\ud0a4\uba74", "\ubc30\ub2ec \ud604\ud669", "\uac70\uc9c0", "\uc774\ub098 \uc694\uae30", "\ub85c\ub529", "\uc870\uae08", "\ubc30\ubbfc", "\uae30\uc874", "\uc774\ub2e4", "20\ubd84", "\uce74\ub4dc", "\ucde8\uc18c", "\uc790 ...

# %% [markdown]
# ## 4. 장바구니 분석

# %%
# 1. [[],[],[]] 형태로 담기

def for_double_array_data(content_list):
    
    main_list = []

    for rv in content_list:
        sub_list = []

        re_rv = re.sub(r'[^0-9a-zA-Z가-힣\s+-]', '', rv)

        noun_list = okt.nouns(re_rv)

        for word in noun_list:
            if len(word) > 1:
                sub_list.append(word)

        main_list.append(sub_list)
        
    return main_list

# %%
# heatmap 그리기

main_list = for_double_array_data(cus_list)

te = TransactionEncoder()
te_arr = te.fit(main_list).transform(main_list)
df = pd.DataFrame(te_arr, columns=te.columns_)

frequent_itemsets = apriori(df, min_support=0.05, use_colnames=True, max_len=2)
frequent_itemsets

rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)
rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']]

rules["antecedents_str"] = rules["antecedents"].apply(lambda x: ",".join(sorted(list(x))))
rules["consequents_str"] = rules["consequents"].apply(lambda x: ",".join(sorted(list(x))))

rules[["antecedents_str", "consequents_str", "support", "confidence", "lift"]]

pivot_data = rules.pivot_table(
    index="antecedents_str",
    columns="consequents_str",
    values="lift", # 'confidence'
    fill_value=0
)

plt.figure(figsize=(10,10))
sns.heatmap(pivot_data, annot=True, cmap="YlGnBu", fmt=".2f", linewidths=0.3, square=True)
plt.title("연관성 분석 시각화(lift 기준)")
plt.xlabel("Consequents")
plt.ylabel("Antecedents")
plt.show()

# ⇒ 단어 연관성에서 ‘쿠폰’, ‘할인’이 강한 연관성으로 등장
# → 소비자가 가장 바라는 것은 ‘쿠폰’ ‘할인’과 같은 금전적 혜택임을 유추 가능

# %%
# 네트워크 분석

# 1. 그래프 생성
G = nx.Graph()

# 2. 엣지 추가
for _, row in rules.iterrows():
    # 단어 추출
    antecedent = ",".join(row["antecedents"])
    consequent = ",".join(row["consequents"])
    weight = row["confidence"]

    # 노드 추가
    G.add_edge(antecedent, consequent, weight=weight)

# 3. 노드 배치
# pos = nx.kamada_kawai_layout(G)
pos = nx.spring_layout(G, seed=13, k=2) # k가 노드간 분산되게 해줌

# 4. 가중치 추출 
edge_weights = [G[u][v]["weight"] for u, v in G.edges()]

# 5. 노드 스타일 지정 및 그리기
plt.figure(figsize=(10,10))
nx.draw_networkx_nodes(G, pos, node_color="lightblue", node_size=1000) # 점
nx.draw_networkx_edges(G, pos, edge_color="gray", width=edge_weights) # 선
nx.draw_networkx_labels(G, pos, font_size=12, font_family="Malgun Gothic")

edge_labels = {(u, v): f"{d['weight']:.2f}" for u, v, d in G.edges(data=True)}
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=5)

plt.title("단어 간 연관 규칙 기반 네트워크 그래프(Lift 기준)")
plt.axis("off")
plt.show()

# %% [markdown]
# ## * 특정 키워드들로 복수개 파일에서 검색후 단어별로 문자열 추출(https://www.tippingkorea.co.kr : 워드클라우드 활용(구분자 ' '))

# %%
raw_cus_data1 = pd.read_csv('data/구글플레이스토어_땡겨요_리뷰.csv')
raw_cus_data2 = pd.read_csv('data/구글플레이스토어_당근_리뷰.csv')
raw_cus_data3 = pd.read_csv('data/구글플레이스토어_배달의민족_리뷰.csv')
raw_cus_data4 = pd.read_csv('data/구글플레이스토어_쿠팡이츠-배달앱_리뷰.csv')

okt = Okt()

stop_words = ['주문', '배달', '쿠폰', '메뉴', '어플', '결제', '가게', '사용'] 

def make_word_str(review):

    # 1. 정규표현식 정제
    review = re.sub(r'[^0-9a-zA-Z가-힣\s+-]', '', review)

    # 2. 형태소 분석
    result = okt.nouns(review)
    
    words = []
    
    for word in result:
        if len(word) > 1 and word not in stop_words:
            words.append(word)
                
    return ' '.join(words)

cus_keyword = ['지역', '지역화폐', '페이', '동네']

cus_data_list = [(raw_cus_data1, '땡겨요'), (raw_cus_data2, '당근'), (raw_cus_data3, '배민'), (raw_cus_data4, '쿠팡이츠')]

for data, name in cus_data_list:

    for keyword in cus_keyword:
        
        txt_str = ''
        
        for review in data['content'].tolist():
            if keyword in review:
                txt_str = txt_str + make_word_str(review) + ' '
                
        with open(f"keyword_txt\\{name}-{keyword}.txt", "w", encoding='utf-8') as f:
            f.write(txt_str)
